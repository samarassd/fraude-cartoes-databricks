# %%
# %sql 
CREATE CATALOG IF NOT EXISTS fraud_lab;

CREATE SCHEMA IF NOT EXISTS fraud_lab.bronze;

CREATE VOLUME IF NOT EXISTS fraud_lab.bronze.raw_files;

CREATE SCHEMA IF NOT EXISTS fraud_lab.silver;
CREATE SCHEMA IF NOT EXISTS fraud_lab.gold;
CREATE SCHEMA IF NOT EXISTS fraud_lab.monitoring;

CREATE VOLUME IF NOT EXISTS fraud_lab.monitoring.artifacts;

# %%
# %sql

SHOW SCHEMAS IN fraud_lab;

# %%
# %sql

SHOW VOLUMES IN fraud_lab.bronze

# %%
# %sql

SHOW VOLUMES IN fraud_lab.monitoring;
