# %%
CATALOG = "fraud_lab"

BRONZE = f"{CATALOG}.bronze"
SILVER = f"{CATALOG}.silver"
GOLD = f"{CATALOG}.gold"
MONITORING = f"{CATALOG}.monitoring"

RAW_VOLUME = f"/Volumes/{CATALOG}/bronze/raw_files"
ARTIFACT_VOLUME = f"/Volumes/{CATALOG}/monitoring/artifacts"

FILES = {
    "fraud_train": "fraudTrain.csv",
    "fraud_test": "fraudTest.csv",
}

TABLE_BRONZE_TRAIN = f"{BRONZE}.fraud_train"
TABLE_BRONZE_TEST = f"{BRONZE}.fraud_test"

TABLE_SILVER_TRAIN = f"{SILVER}.fraud_train"
TABLE_SILVER_TEST = f"{SILVER}.fraud_test"

TABLE_BASE = f"{SILVER}.transacoes_base"
TABLE_FEATURES = f"{GOLD}.transacoes_features"
TABLE_DECISIONS = f"{GOLD}.decisoes_simuladas"

TABLE_CASES = f"{MONITORING}.casos"
TABLE_MONITOR = f"{MONITORING}.monitor_diario"
TABLE_RETRO = f"{MONITORING}.monitor_retrospectivo"

TIMEZONE = "UTC"
DEV_TIME_FRACTION = 0.80

SAMPLE_MOD = 20
SAMPLE_BUCKET = 0
MAX_PANDAS_ROWS = 150_000
