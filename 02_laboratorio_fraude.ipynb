# %%
# %run ./00_config

# %%
from pyspark.sql import functions as F

# %%
fraud_test = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .csv(f"{RAW_VOLUME}/{FILES['fraud_test']}")
    )

# %%
display(fraud_test.limit(10))

# %%
fraud_train = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .csv(f"{RAW_VOLUME}/{FILES['fraud_train']}")
)

# %%
display(fraud_train.limit(10))

# %%
fraud_test.dtypes

# %%
fraud_train.dtypes

# %%
fraud_train = (
    fraud_train
    .withColumnRenamed("cc_num", "card_id")
    .withColumnRenamed("trans_num", "tx_id")
    .withColumnRenamed("trans_date_trans_time", "event_ts")
    .withColumnRenamed("amt", "amount")
)

# %%
fraud_test = (
    fraud_test
    .withColumnRenamed("cc_num", "card_id")
    .withColumnRenamed("trans_num", "tx_id")
    .withColumnRenamed("trans_date_trans_time", "event_ts")
    .withColumnRenamed("amt", "amount")
)

# %% [markdown]
# #### Verificando chave vazia/repetida, timestamp invalido, amount negativo e label diferente de 0/1.

# %%
fraud_test.filter(F.col("card_id").isNull()).count()

# %%
display(
    fraud_test.select("card_id").distinct().count()
)

# %%
fraud_test.count()

# %%
display(
    fraud_test.select("is_fraud").distinct()
)

# %%
(
    fraud_test 
    .select('*')
    .filter(
    F.col("amount") < 0)
).count()

# %%
(
    fraud_test
    .select('event_ts')
).show()

# %%
(
    fraud_test
    .filter(
        F.col("event_ts").isNull()
    )
).count()
